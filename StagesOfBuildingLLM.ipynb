# %% [markdown]
# # Stages of Building Large Language Model

# %% [markdown]
# ## Architecture Diagram
#
# ![Screenshot 2025-01-08 at 1.12.26 PM.png](attachment:b0509d76-1770-469b-8778-4b16df7cf9e1.png)

# %% [markdown]
# ### Stage1 Building a large Language Model (LLM Basics)
# **Data Preparation and Sampling**\
# *How data is collected from different datasets\
# *How data is processed\
# *How data is sampled\
# It will consist of Tokenization, Embedding, Postional encoding, batching data
#
#
# **Attention Mechanism**\
# *Simple Attention Mechanism\
# *Self Attention with trainable wieghts\
# *Causal Attention\
# *Multihead Attention\
#
# **LLM Architecture**\
# *How different Layers are stacked on to each other\
# *Where will attention head go
#
# Once we have constructed the large language Model we will proceed to Stage 2 - also known as pre-training stage.This will train the data on the underlying dataset.So the outcome of stage two is to build a foundational model on unlabelled data.

# %% [markdown]
# # Stage 2 Foundation Model
#
# ## Training Loop
#
# *A typical training loop for training deep neural networks in PyTorch consists of numerous steps, iterating over the batches in the training set for several epochs. In each loop, we calculate the loss for each training set batch to determine loss gradients, which we use to update the model weights so that the training set loss is minimized.
#
# ![Screenshot 2025-01-08 at 3.21.11 PM.png](attachment:63b3e454-5a2c-47f6-8aa2-ff7983a4b797.png)
#
#
# ## Model Evaluation and Loading Pretrained Weight
#
# ![Screenshot 2025-01-08 at 3.26.59 PM.png](attachment:4335018e-4240-412f-b16f-f51f36624202.png)
#
#
# *Text Generation: The process begins by encoding the input text into token IDs, which are then fed into the GPT model. The outputs of the model are then converted back into text and appended to the original input text.
#
# *Model Evaluation: The text evaluation process measures “how far” the generated tokens are from the correct predictions (targets). The training function will use this information to adjust the model weights to generate text that is more similar to (or, ideally, matches) the target text.
#
# *Training and Validation loss: Having computed the cross entropy loss, we apply this loss computation to the entire text dataset that we will use for model training.

# %% [markdown]
# # Stage 3 Finetuning
#
# Once we have coded the LLM architecture, pretrained it, and learned how to import pretrained weights from an external source, such as OpenAI, into our model. Now we will be in a position to fine-tuning the LLM on a specific target task, such as classifying text.For example we can examine by classifying text messages as “spam” or “not spam.”
# The most common ways to fine-tune language models are instruction fine-tuning and classification fine-tuning.
#
# *Instruction Fine tuning: Instruction fine-tuning involves training a language model on a set of tasks using specific instructions to improve its ability to understand and execute tasks described in natural language prompts.
#
# *Classifier Finetuning: In classification fine-tuning, the model is trained to recognize a specific set of class labels, such as “spam” and “not spam.” A key point is that a classification fine-tuned model is restricted to predicting classes it has encountered during its training.
